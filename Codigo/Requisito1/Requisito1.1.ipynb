# %% [markdown]
# Importacion de varias bibliotecas y modulos de Selenium, que es una herramienta para automatizar la interaccion con navegadores web.

# %%
from selenium import webdriver #Importa el módulo principal para controlar un navegador web.
from selenium.webdriver.chrome.service import Service #Permite definir un servicio para el navegador Chrome.
from selenium.webdriver.chrome.options import Options #Permite configurar opciones para Chrome, como ejecutar en modo sin interfaz gráfica (headless).
from selenium.webdriver.common.by import By #Define estrategias para ubicar elementos en una página, como By.ID, By.XPATH, etc.
from selenium.webdriver.support.ui import WebDriverWait #Permite esperar hasta que se cumpla una condición antes de continuar con la ejecución del script.
from selenium.webdriver.support import expected_conditions as EC #Contiene condiciones predefinidas, como esperar que un elemento sea visible o clickeable.
from webdriver_manager.chrome import ChromeDriverManager #Descarga y administra automáticamente la versión correcta del controlador de Chrome.
import time #Proporciona funciones para manejar pausas en la ejecución del script.
import sys #Permite manejar rutas del sistema
import os #Permite interactuar con el sistema operativo, útil para manejar archivos o variables de entorno.
from datetime import datetime #Permite manejar fechas y horas en Python. Es útil si necesitas registrar timestamps o generar nombres de archivos con la fecha actual.
from selenium.webdriver.support.ui import Select #Se usa para interactuar con elementos select en formularios HTML, como listas desplegables (dropdowns) y permite permite seleccionar opciones por índice, valor o texto visible
from selenium.webdriver.common.keys import Keys #Permite enviar teclas como Enter, Tab o Ctrl+C a un campo de entrada.
from selenium.common.exceptions import TimeoutException, ElementClickInterceptedException, NoSuchElementException, StaleElementReferenceException #Importa excepciones comunes en Selenium para manejar errores

# %% [markdown]
# Asegurar de que existe un directorio llamado "articles" en la ruta absoluta del script. Si no existe, lo crea.

# %%
download_path = os.path.abspath("../../Bases_de_datos") #Obtener la ruta absoluta de la carpeta "articles".
if not os.path.exists(download_path): #Verifica si la carpeta "articles" existe en la ruta absoluta.
    os.makedirs(download_path) #Si la carpeta no existe, la crea automáticamente.

# %% [markdown]
# Configurar las opciones del navegador Chrome en Selenium y luego iniciar sesion

# %%
options = Options()
options.add_argument("--start-maximized")

# Perfil temporal en lugar del real
options.add_argument("--user-data-dir=C:/Temp/ChromeProfile")

# Solución típica para DevToolsActivePort
options.add_argument("--remote-debugging-port=9222")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %% [markdown]
# Abrir un proxy en Selenium cargando la URL de inicio de sesión de un servicio de proxy

# %%
#Definir la URL del proxy
proxy_url = "https://login.intelproxy.com/v2/inicio?cuenta=7Ah6RNpGWF22jjyq" #Almacena la dirección de un servicio de proxy (IntelProxy en este caso).
#Cargar la URL en el navegador controlado por Selenium
driver.get(proxy_url) #Selenium abre la página del proxy en Google Chrome (o el navegador que se esté usando)

# %% [markdown]
# Dar click en boton de iniciar sesion con Google

# %%
# Encuentra el botón por su ID y haz clic en él
boton = driver.find_element(By.ID, "btn-google")
boton.click()

# %% [markdown]
# Intentar iniciar sesión en Gmail automáticamente con un correo y contraseña predefinidos.

# %%
#Intentar encontrar el campo de correo electrónico
try:
    #Espera hasta 5 segundos para encontrar el campo de entrada de correo (ID="identifierId"), Si el campo aparece antes, continúa sin esperar más.
    email_input = WebDriverWait(driver, 5).until(
        EC.presence_of_element_located((By.ID, "identifierId"))
    )
    #Escribir el correo y presionar Enter
    email_input.send_keys("correo")
    email_input.send_keys(Keys.RETURN)

    print("✅ Usuario de Gmail ingresado.") #Mensaje informativo

    #Esperar hasta que aparezca el campo de contraseña, espera hasta 5 segundos para que aparezca el campo de contraseña (NAME="Passwd"), Si aparece antes, sigue con la ejecución.
    password_input = WebDriverWait(driver, 5).until( #Espera hasta que aparezca el campo de contraseña, espera hasta 10 segundos para que aparezca el campo de contraseña (NAME="Passwd"), Si aparece antes, sigue con la ejecución.
        EC.presence_of_element_located((By.NAME, "Passwd"))
    )
    #Escribir la contraseña y presionar Enter
    password_input.send_keys("clave")
    password_input.send_keys(Keys.RETURN)

    print("✅ Contraseña de Gmail ingresada.") #Mensaje informativo

#Manejar errores si ya se está autenticado    
except:
    print("⚠️ No se necesitó login de Gmail (ya estabas autenticado).") #Mensaje informativo
print("📂 Página actual:", driver.current_url) #Mensaje informativo

# %% [markdown]
# Abrir una página web de ScienceDirect a través de un proxy del CRAI

# %%
#Definir la URL de acceso con proxy
url_sd = "https://www-sciencedirect-com.crai.referencistas.com/" #url_sd almacena la dirección de ScienceDirect a través de un proxy institucional del CRAI, crai.referencistas.com es un proxy académico que permite a usuarios acceder a recursos de pago usando credenciales institucionales.
#Abrir la página en Selenium
driver.get(url_sd) #Selenium abre la URL en el navegador controlado automáticamente.

# %% [markdown]
# Establecer palabra de busqueda

# %%
search_query = '"generative artificial intelligence"'

# %% [markdown]
# Realizar la búsqueda del sitio web usando Selenium.

# %%
#Esperar hasta que aparezca el campo de búsqueda
campo_input = WebDriverWait(driver, 10).until( #WebDriverWait(driver, 10).until(...): Espera hasta 10 segundos para que aparezca un elemento en la página
    EC.presence_of_element_located((By.ID, "qs")) #By.ID, "qs": Busca el campo de búsqueda por su id="qs"
)
#Escribir el término de búsqueda
campo_input.send_keys(search_query) #Envía el texto "computational thinking" al campo de búsqueda.
campo_input.send_keys(Keys.RETURN) #Presionar "Enter" para ejecutar la búsqueda

# %% [markdown]
# Esperar a que aparezca un botón con el texto "100" y luego hace clic en él.

# %%
#Esperar hasta que el botón "100" esté disponible para hacer clic
option_100 = WebDriverWait(driver, 10).until( #Espera hasta 10 segundos para que el elemento esté listo para hacer clic.
    EC.element_to_be_clickable((By.XPATH, "//span[contains(@class, 'anchor-text') and text()='100']")) #By.XPATH, "//span[contains(@class, 'anchor-text') and text()='100']", Busca un elemento <span> que tenga la clase "anchor-text", El texto exacto dentro del <span> debe ser "100".
)
option_100.click() #Hacer clic en la opción "100"
print("✅ Se seleccionó la opción '100'.") #Mensaje informativo
# Out:
# ✅ Se seleccionó la opción '100'.

# %% [markdown]
# Buscar y seleccionar la casilla de verificación ("checkbox") que permite marcar todos los resultados.

# %%
#Esperar hasta que el checkbox esté presente en la página
select_all_checkbox = WebDriverWait(driver, 10).until( #WebDriverWait(driver, 15).until(...), Espera hasta 15 segundos a que el checkbox aparezca en la página.
    EC.presence_of_element_located((By.XPATH, "//input[@id='select-all-results']")) #EC.presence_of_element_located(...):, Asegura que el checkbox esté presente en el DOM (aunque no sea interactuable todavía), By.XPATH, "//input[@id='select-all-results']":, Busca un elemento <input> con el atributo id="select-all-results"., Este identificador suele usarse en páginas que permiten seleccionar todos los artículos o resultados con un solo clic.
)
#Hacer clic en la casilla de selección usando JavaScript
driver.execute_script("arguments[0].click();", select_all_checkbox) #execute_script("arguments[0].click();", select_all_checkbox):, Usa JavaScript para forzar el clic en el checkbox.
print("✅ Todos los artículos han sido seleccionados correctamente.") #Mensaje informativo
# Out:
# ✅ Todos los artículos han sido seleccionados correctamente.

# %% [markdown]
# Configurar la ruta de descarga del navegador Chrome para que los archivos descargados

# %%
#Definir la ruta de descarga personalizada
custom_download_path = r"C:\Proyecto Final\Bases_de_datos\science_direct" #Se usa para evitar problemas con las barras invertidas (\) en Windows.
#Configurar la descarga automática en Chrome
driver.execute_cdp_cmd("Page.setDownloadBehavior", { #execute_cdp_cmd("Page.setDownloadBehavior", {...}):, usa el Chrome DevTools Protocol (CDP) para modificar el comportamiento de descarga del navegador.
    "behavior": "allow", #"behavior": "allow" → Permite descargas sin mostrar el cuadro de diálogo de confirmación.
    "downloadPath": custom_download_path #"downloadPath": custom_download_path → Define la carpeta donde se guardarán los archivos.
})
print(f"✅ Descargas configuradas en: {custom_download_path}") #Mensaje informativo
# Out:
# ✅ Descargas configuradas en: C:\Proyecto Final\Bases_de_datos\science_direct

# %% [markdown]
# Automatizar la descarga de citas en formato RIS desde una página de resultados de búsqueda

# %%
#Bucle para procesar todas las páginas
while True: #Permite descargar citas de varias páginas sin intervención manual.
    try: #Se romperá cuando no haya más páginas disponibles o haya un error.
        # Hacer clic en "Export"
        #Encuentra y hace clic en el botón "Export" dentro de la página.
        export_button = WebDriverWait(driver, 5).until(
            EC.element_to_be_clickable((By.XPATH, "//button[contains(@class, 'export-all-link-button') and .//span[contains(text(), 'Export')]]"))
        )
        export_button.click()
        print("✅ Botón 'Export' clickeado correctamente.") #Mensaje informativo

        #Hacer clic en "Export citation to RIS"
        #Hace clic en la opción para descargar la citación en formato .ris.
        export_ris_button = WebDriverWait(driver, 5).until(
            EC.element_to_be_clickable((By.XPATH, "//span[contains(@class, 'button-link-text') and text()='Export citation to RIS']"))
        )
        export_ris_button.click()
        print("✅ Botón 'Export citation to RIS' clickeado correctamente.") #Mensaje informativo

        #Esperar la descarga del archivo .ris
        print("⏳ Esperando la descarga del archivo RIS...") #Mensaje informativo
        timeout = 5 #Tiempo limite de 5 segundos
        start_time = time.time() #Guarda el tiempo de inicio en segundos.
        downloaded = False #Variable de control para indicar si el archivo se ha descargado.

        #Monitorea la carpeta de descargas (download_path) durante 5 segundos en busca del archivo .ris.
        while time.time() - start_time < timeout:
            #Buscar archivos .ris en la carpeta de descargas
            ris_files = [f for f in os.listdir(download_path) if f.endswith(".ris")] #os.listdir(download_path): Lista todos los archivos en la carpeta de descargas., if f.endswith(".ris"): Filtra solo los archivos con extensión .ris.
            #Si se encuentra, imprime el nombre del archivo y continúa.
            if ris_files:
                print(f"✅ Archivo RIS descargado: {ris_files[-1]}") #Imprime el nombre del último archivo descargado (ris_files[-1]).
                downloaded = True #Cambia downloaded = True para indicar que la descarga fue exitosa.
                break #Usa break para salir del bucle, ya que el archivo fue encontrado
            time.sleep(1) #Esperar 1 segundo
        #Si no se encuentra, muestra un mensaje de advertencia.
        if not downloaded:
            print("⚠️ Advertencia: No se detectó ningún archivo RIS después de 5 segundos.") #Mensaje informativo

        #Cerrar la ventana modal (si existe)
        try:
            #Si la ventana de exportación sigue abierta, la cierra.
            close_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[contains(@class, 'modal-close-button')]"))
            )
            close_button.click()
            print("✅ Ventana modal cerrada correctamente.") #Mensaje informativo
            time.sleep(1)
        #Si no encuentra el botón, ignora el error y continúa.    
        except TimeoutException:
            print("⚠️ No se encontró el botón de cierre de la ventana modal. Continuando...") #Mensaje informativo

        #Verificar si hay una página siguiente y navegar
        try:
            #Busca el botón "Next" (siguiente página).
            next_button = WebDriverWait(driver, 5).until( #Se usa WebDriverWait(driver, 5).until(...) para esperar hasta 5 segundos a que aparezca el botón "Next".
                EC.presence_of_element_located((By.XPATH, "//a[@data-aa-name='srp-next-page']")) #EC.presence_of_element_located(...): Se asegura de que el botón esté presente en el DOM.
            )
            next_url = next_button.get_attribute("href") #Se extrae el atributo href del botón, que contiene el enlace a la siguiente página.
            #Si no existe, termina el bucle y la automatización.
            if not next_url:
                print("✅ No hay más páginas disponibles.") #Mensaje informativo
                break #Cortar la ejecucion

            # ✅ Hacer scroll hasta "Next"
            driver.execute_script("arguments[0].scrollIntoView();", next_button) #Se usa execute_script para hacer un scroll automático hasta el botón "Next".
            time.sleep(1) #Esperar 1 segundo

            #Intentar clic normal, si falla usar JavaScript
            try:
                next_button.click()
            except ElementClickInterceptedException:
                driver.execute_script("arguments[0].click();", next_button)
            print(f"➡️ Se hizo clic en 'Next'. Nueva URL: {next_url}") #Mensaje informativo

            # ✅ Esperar hasta que la URL cambie
            WebDriverWait(driver, 5).until(lambda d: d.current_url == next_url)
            time.sleep(1) #Esperar 1 segundo

        except (TimeoutException, NoSuchElementException):
            print("✅ No hay más páginas disponibles.") #Mensaje informativo
            break #Cortar la ejecucion

    except Exception as e:
        print(f"⚠️ Error inesperado: {e}") #Mensaje informativo
        break #Cortar la ejecucion
# Out:
# ✅ Botón 'Export' clickeado correctamente.
# ✅ Botón 'Export citation to RIS' clickeado correctamente.
# ⏳ Esperando la descarga del archivo RIS...
# ⚠️ Advertencia: No se detectó ningún archivo RIS después de 5 segundos.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 43
#      40 #Cerrar la ventana modal (si existe)
#      41 try:
#      42     #Si la ventana de exportación sigue abierta, la cierra.
# ---> 43     close_button = WebDriverWait(driver, 5).until(
#      44         EC.element_to_be_clickable((By.XPATH, "//button[contains(@class, 'modal-close-button')]"))
#      45     )
#      46     close_button.click()
#      47     print("✅ Ventana modal cerrada correctamente.") #Mensaje informativo
#
# ...

# %% [markdown]
# Abre  la pagina de SAGE en el navegador controlado por Selenium

# %%
url_sage = "https://journals-sagepub-com.crai.referencistas.com/" #Definir URL
driver.get(url_sage) #Carga la página en el navegador, driver es el objeto de Selenium WebDriver que controla el navegador y presiona enter

# %% [markdown]
# Buscar un campo de entrada en la página web y envía una consulta de búsqueda con la frase "computational thinking".

# %%
#Espera a que el campo de entrada esté disponible
campo_input = WebDriverWait(driver, 10).until( #Usa WebDriverWait(driver, 10).until(...) para esperar hasta 10 segundos a que el campo aparezca en la página.
    EC.presence_of_element_located((By.ID, "AllField35ea26a9-ec16-4bde-9652-17b798d5b6750")) #EC.presence_of_element_located((By.ID, "AllField35ea26a9-ec16-4bde-9652-17b798d5b6750")):, Busca un elemento por su ID (AllField35ea26a9-ec16-4bde-9652-17b798d5b6750)., EC.presence_of_element_located(...) asegura que el campo existe en el DOM, aunque no sea visible aún.
)
#Escribe en el campo de búsqueda
campo_input.send_keys(search_query) #send_keys("computational thinking"): Escribe "computational thinking" en el campo de entrada
campo_input.send_keys(Keys.RETURN) #Simular enter

# %% [markdown]
# Configurar la ruta de descarga del navegador para que los archivos se guarden en una ubicación específica en lugar de la carpeta de descargas predeterminada.

# %%
#Definir la ruta donde se guardarán los archivos descargados.
custom_download_path = r"C:\Proyecto-Final\Bases_de_datos\sage" #Se usa un string crudo (r"") para evitar problemas con las barras invertidas (\).
#Cambia la configuración de descarga del navegador (Chrome).
driver.execute_cdp_cmd("Page.setDownloadBehavior", { #driver.execute_cdp_cmd(...) usa el Chrome DevTools Protocol (CDP) para ejecutar comandos avanzados en Chrome., "Page.setDownloadBehavior": Modifica el comportamiento de descargas del navegador.
    "behavior": "allow", #"behavior": "allow": Permite que las descargas se realicen sin necesidad de confirmación manual.
    "downloadPath": custom_download_path #"downloadPath": custom_download_path: Define la carpeta donde se guardarán los archivos.
})
print(f"✅ Descargas configuradas en: {custom_download_path}") #Mensje informativo

# %% [markdown]
# Acceder a SAGE ya autenticado y extraer artículos

# %%
#Ejecutar hasta que no haya más páginas disponibles
while True:
    try:
        # Espera hasta que el botón de cookies sea clickeable (máximo 5 segundos).
        cookie_button = WebDriverWait(driver, 5).until(
            EC.element_to_be_clickable((By.ID, "onetrust-accept-btn-handler"))
        )
        # Hace clic en el botón de cookies.
        cookie_button.click()
        print("✅ Botón 'Accept Non-Essential Cookies' clickeado correctamente.")
    except TimeoutException:
        print("⚠️ Botón 'Accept Non-Essential Cookies' no encontrado o no clickeable.")
        
    try:
        #Seleccionar todos los artículos de la página actual
        select_all_checkbox = WebDriverWait(driver, 5).until(
            EC.presence_of_element_located((By.ID, "action-bar-select-all"))
        )
        driver.execute_script("arguments[0].click();", select_all_checkbox) # Usa execute_script para forzar el clic en caso de que Selenium no pueda hacerlo directamente.
        print("✅ Todos los artículos han sido seleccionados correctamente.") #Mensaje informativo

        #Exportar las citas seleccionadas
        export_button = WebDriverWait(driver, 5).until(
            EC.element_to_be_clickable((By.XPATH, "//span[text()='Export selected citations']"))
        )
        export_button.click()
        print("✅ Botón 'Export selected citations' clickeado correctamente.") #Mensaje informativo

        #Seleccionar el formato "RIS"
        select_element = WebDriverWait(driver, 5).until(
            EC.presence_of_element_located((By.ID, "citation-format"))
        )
        select = Select(select_element)
        select.select_by_value("ris")
        print("✅ Formato 'RIS' seleccionado correctamente.") #Mensaje informativo
        #Descargar la cita exportada
        download_button = WebDriverWait(driver, 5).until(
            EC.element_to_be_clickable((By.XPATH, "//a[contains(@class, 'download__btn') and contains(text(), 'Download citation')]"))
        )

        #Si el clic normal falla, usa JavaScript para forzar el clic.
        try:
            download_button.click()
        except ElementClickInterceptedException:
            print("⚠️ Click interceptado, usando JavaScript...")
            driver.execute_script("arguments[0].click();", download_button)
        print("✅ Botón 'Download citation' clickeado correctamente.") #Mensaje informativo
        time.sleep(3) #Esperar 1 segundo
        #Buscar el archivo descargado más reciente y lo renombra
        ris_files = [f for f in os.listdir(custom_download_path) if f.endswith(".ris")]
        if ris_files:
            latest_file = max(ris_files, key=lambda f: os.path.getctime(os.path.join(custom_download_path, f)))
            old_path = os.path.join(custom_download_path, latest_file)
            #Generar nuevo nombre con fecha y hora
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            new_filename = f"sage_{timestamp}.ris"
            new_path = os.path.join(custom_download_path, new_filename)
            #Renombrar el archivo
            os.rename(old_path, new_path)
            print(f"✅ Archivo renombrado: {new_filename}")
        else:
            print("⚠️ No se encontró ningún archivo RIS.")

        #Intentar cerrar la modal
        try:
            modal = WebDriverWait(driver, 5).until(
                EC.presence_of_element_located((By.CLASS_NAME, "modal__header"))
            )
            print("✅ Modal detectada.")
            close_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//div[@class='modal__header']//button[@data-dismiss='modal']"))
            )
            #Intentar cerrar la modal con clic normal
            close_button.click()
            time.sleep(1) #Esperar 2 segundos
            #Si sigue abierta, intentar con JavaScript
            if modal.is_displayed():
                driver.execute_script("arguments[0].click();", close_button)
                time.sleep(1)
            #Enviar tecla ESC si aún sigue abierta
            if modal.is_displayed():
                from selenium.webdriver.common.keys import Keys
                driver.find_element(By.TAG_NAME, "body").send_keys(Keys.ESCAPE)
                time.sleep(1)
            #Si aún no se cierra, eliminarla del DOM
            if modal.is_displayed():
                driver.execute_script("document.querySelector('.modal__header').remove();")
                time.sleep(1)
            print("✅ Modal cerrada correctamente.")
        except TimeoutException:
            print("⚠️ No se detectó la modal o ya estaba cerrada.")

        #Avanzar a la siguiente página (si existe)
        try:
            next_button = WebDriverWait(driver, 5).until(
                EC.presence_of_element_located((By.CSS_SELECTOR, 'li.page-item__arrow--next a'))
            )
            #Obtener la URL de la siguiente página
            next_page_url = next_button.get_attribute('href')
            #Verificar si hay más páginas
            if not next_page_url:
                print("✅ No hay más páginas disponibles. Finalizando la navegación.")
                break
            print(f"📌 Avanzando a la siguiente página: {next_page_url}") #Mensaje informativo
            #Hacer clic en "Next" usando JavaScript
            driver.execute_script("arguments[0].click();", next_button)
            time.sleep(1) #Esperar 1 segundo
        except (NoSuchElementException, TimeoutException, StaleElementReferenceException):
            print("✅ No hay más páginas disponibles. Finalizando la navegación.")
            break

    except Exception as e:
        print(f"⚠️ Error inesperado: {e}")
        break  # Salir en caso de error grave
